# %%
#math
import math as mt

# %%
mt.sqrt(4)
# Out:
# 2.0

# %%
dir(mt)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
mt.sqrt(654)
# Out:
# 25.573423705088842

# %%
round(mt.sqrt(654),2)
# Out:
# 25.57

# %%
mt.pow(7,2)
# Out:
# 49.0

# %%
int(mt.sqrt(654))
# Out:
# 25

# %%
mt.ceil(mt.sqrt(654))
# Out:
# 26

# %%
mt.floor(mt.sqrt(654))
# Out:
# 25

# %%
def ff(r):
    return mt.pi*(r*r)

# %%
ff(4)
# Out:
# 50.26548245743669

# %%
mt.exp(2)
# Out:
# 7.38905609893065

# %%
mt.e
# Out:
# 2.718281828459045

# %%
mt.log(8,2)
# Out:
# 3.0

# %%
mt.fabs(-9)
# Out:
# 9.0

# %%
abs(-9.22)
# Out:
# 9.22

# %%
import time as t

# %%
print(dir(t))
# Out:
# ['_STRUCT_TM_ITEMS', '__doc__', '__loader__', '__name__', '__package__', '__spec__', 'altzone', 'asctime', 'ctime', 'daylight', 'get_clock_info', 'gmtime', 'localtime', 'mktime', 'monotonic', 'monotonic_ns', 'perf_counter', 'perf_counter_ns', 'process_time', 'process_time_ns', 'sleep', 'strftime', 'strptime', 'struct_time', 'thread_time', 'thread_time_ns', 'time', 'time_ns', 'timezone', 'tzname']

# %%
t.time()
# Out:
# 1728975193.050975

# %%
start=t.time()
for i in range(1,10877):
    print('',end="")

end=t.time()
print(start)
print(end)
print(end-start)
# Out:
# 1728975308.3153691
# 1728975308.3931677
# 0.07779860496520996

# %%
t.ctime()
# Out:
# 'Tue Oct 15 12:25:44 2024'

# %%
t.localtime()
# Out:
# time.struct_time(tm_year=2024, tm_mon=10, tm_mday=15, tm_hour=12, tm_min=26, tm_sec=41, tm_wday=1, tm_yday=289, tm_isdst=0)

# %%
t.tzname
# Out:
# ('India Standard Time', 'India Daylight Time')

# %%
s=t.time()
for i in range(1,500):
    print('hello how are you')

e=t.time()
print(e-s)
# Out:
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# ...

# %%
s=t.time()
print(s)
i=0
while i<500:
    print('hello how are you')
    i+=1
    
e=t.time()
print(e)
print(e-s)
# Out:
# 1728976358.452615
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# hello how are you
# ...
